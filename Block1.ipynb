# %%
import numpy as np
import matplotlib.pylab as plt
import pickle

# %% [markdown]
# ## Construct CGT Objects (at different T)

# %%
filename = 'Block1_CGT.pkl'

with open(filename,'rb') as file:
    CGT01 = pickle.load(file)
    CGT03 = pickle.load(file)
    CGT04 = pickle.load(file)
    CGT05 = pickle.load(file)
    CGT1 = pickle.load(file)
    CGT2 = pickle.load(file)
    CGT5 = pickle.load(file)

#List containing all objects
lsCGTBl1 = [CGT01,CGT03,CGT04,CGT05,CGT1,CGT2,CGT5]
# %store lsCGTBl1
#This allows analysis between different configurations in the DiffConfig ipynb file

# %%
filename = 'Block1_CGT_H.pkl'

with open(filename,'rb') as file:
    CGT01_H = pickle.load(file)
    CGT03_H = pickle.load(file)

# %% [markdown]
# ## Force Extension

# %%
#Ree
for cgt in lsCGTBl1[0:2]:
    plt.plot(cgt.aveRee/99, cgt.f,'o-', color = cgt.color, label = 'T = ' + str(cgt.t))

for cgt in lsCGTBl1[2:3]:
    plt.plot(cgt.aveRee/99, cgt.f,'o--', color = cgt.color, label = 'T = ' + str(cgt.t))

plt.legend()
plt.ylabel('Force ($\epsilon$/$\sigma$)', fontsize=16)
plt.xlabel('<$R_{ee}$/Nb>', fontsize=16)
plt.title('Alternating, below and near $T_c$')
# plt.savefig('../Data/Block1/Figures/FvsRee')
# Out:
# Text(0.5, 1.0, 'Alternating, below and near $T_c$')

# %%
# Below Critical Temperature
for cgt in lsCGTBl1[0:2]:
    force = np.array(cgt.f)
    Ree = np.array(cgt.aveRee)
    plt.plot(Ree / 99, force / cgt.t, 'o-', color = cgt.color, label = 'T = ' + str(cgt.t))

for cgt in lsCGTBl1[2:3]:
    force = np.array(cgt.f)
    Ree = np.array(cgt.aveRee)
    plt.plot(Ree / 99, force / cgt.t, 'o--', color = cgt.color, label = 'T = ' + str(cgt.t))

x = np.linspace(0.1, 50)
y = 1 / np.tanh(x) - 1 / x
plt.plot(y,x, color = 'k', label = '$R_{FJC}(f, T)$')

plt.ylabel('$fb/kT$', fontsize=16)
plt.xlabel('<$R_{ee}$/Nb>', fontsize=16)
plt.legend(frameon=False)
plt.title("Alternating, below and near $T_c$")
# plt.savefig('../Data/Block1/Figures/Fbkt vs Ree')
# plt.xlim(-1,11)
# plt.savefig('../Data/Block1/Figures/Fbkt vs ReeZoom')
# Out:
# Text(0.5, 1.0, 'Alternating, below and near $T_c$')

# %%
cgt = CGT01
force = np.array(cgt.f)
Ree = cgt.aveRee
plt.plot(Ree / 99, force / 0.1, 'o-', label = 'Unloading T = 0.1')

cgt_h = CGT01_H
force = np.array(cgt_h.f)
Ree = cgt_h.aveRee
plt.plot(Ree / 99, force / 0.1, 'bo-', label = 'Loading T = 0.1')

cgt = CGT03
force = np.array(cgt.f)
Ree = cgt.aveRee
plt.plot(Ree / 99, force / 0.3, 'o-', label = 'Unloading T = 0.3')

cgt_h = CGT03_H
force = np.array(cgt_h.f)
Ree = cgt_h.aveRee
plt.plot(Ree / 99, force / 0.3, 'o-', color = 'gold', label = 'Loading T = 0.3')

plt.ylabel('$fb/kT$', fontsize=16)
plt.xlabel('<$R_{ee}$/Nb> ($\sigma$)', fontsize=16)
plt.legend(frameon=False)
plt.title("fb/kT vs. Ree for alternating")
# Out:
# Text(0.5, 1.0, 'fb/kT vs. Ree for alternating')

# %% [markdown]
# ## Cyclic Loading

# %%
#Cyclic Loading
#Cycling between f = 2, 4, 7, 3
path = '../block1/T0.1/cyclic/dump'
with open(path, 'r') as file:
        
    LINES = file.readlines()
    
    Nf = len(LINES) // (10009)

    file.seek(0) # go back to start of file

    all_frames=[]

    while True:
        # Skip the non-numeric header lines (assumed to be 9 lines)
        for _ in range(9):
            line = file.readline()
            if not line:
                break  # End of file
        else:
            # Read the next block of data
            frame_data = np.loadtxt(file, max_rows=10000)
            all_frames.append(frame_data)
            continue
        break  # Exit the loop if EOF

# Combine all frames into a single numpy array
D = np.vstack(all_frames).reshape(Nf,10000,9)

#Sort each frame by atom type
for f in range(Nf):
    ids = D[f,:,0]
    key = np.argsort(ids)
    D[f,:,:] = D[f,key,:]

Nf = D.shape[0]

#Extract all atoms that are type 3
Type2 = D[D[:,:,2] == 3]
Type2 = Type2.reshape(Nf, 100, 9)

#Extract all atoms that are type 4
Type3 = D[D[:,:,2] == 4]
Type3 = Type3.reshape(Nf, 100, 9)

#Extract Position vector
Type2 = Type2[:,:,3:6]
Type3 = Type3[:,:,3:6]

dX = Type2-Type3
Ree = np.linalg.norm(dX, axis = 2)
aveRee = np.mean(Ree, axis = 1)
plt.plot(np.linspace(1, Nf, Nf), aveRee)

# %%
lsRee = np.array([val for idx, val in enumerate(aveRee) if idx % 100 == 99])
force = np.array([2, 1.5, 1, 1.5, 2])
for i in range(5):
    plt.plot(lsRee[4*i:4*i+5], force / 0.1, 'o-', label = f'cycle {i+1}')

plt.plot(lsRee[-4:], force[0:4] / 0.1, 'o-', label = f'cycle {i+1}')
plt.legend()
